# %%
print("hello")
# Out:
# hello

# %%
#os,math ,re
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\salon\\OneDrive\\Desktop\\data science\\os'

# %%
os.mkdir("saloni")

# %%
os.makedirs(r"hello\hii\i\dev")

# %%
os.getcwd()
# Out:
# 'c:\\Users\\salon\\OneDrive\\Desktop\\data science\\os'

# %%
# os.chdir()             ##change directory
# os.rmdir()              ##remove directory
# os.removedirs("path")  # drop directory

# %%
os.stat(r"C:\Users\salon\OneDrive\Desktop\data science\os\hello")   ##copy path of hello file
# Out:
# os.stat_result(st_mode=16749, st_ino=1125899907739761, st_dev=3424610401, st_nlink=1, st_uid=0, st_gid=0, st_size=0, st_atime=1779879607, st_mtime=1779879166, st_ctime=1779879159)

# %%
os.startfile(r"C:\Users\salon\OneDrive\Desktop\data science\os\hello")        ##it is used to start a file

# %%
# os.rename  ##rename the directory

# %%
os.path.isfile(r"C:\Users\salon\OneDrive\Desktop\data science\os\osmodule.ipynb")# check the path of file
# Out:
# True

# %%
os.path.isdir(r"C:\Users\salon\OneDrive\Desktop\data science\os\hello\hii\i\dev") #check nthe path of directory
# Out:
# True

# %%
os.path.exists(r"C:\Users\salon\OneDrive\Desktop\data science\os\saloni") # check the path that exist or not
# Out:
# True

# %%
path1=r"C:\Windows\assembly\NativeImages_v4.0.30319_64\Microsoft.M870d558a#"
path2=r"C:\Windows\assembly\NativeImages_v4.0.30319_64\Microsoft.M870d558a#"
completepath=os.path.join(path1,path2)
print(os.listdir(completepath))
# Out:
# ['d31e5545a36ace08cbed61785c5b1838']

# %%
os.path.getsize(r"C:\Users\salon\OneDrive\Desktop\data science\os\osmodule.ipynb")
# Out:
# 5642

# %%
os.mkdir
