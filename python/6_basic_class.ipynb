# %% [markdown]
# ### class
# it acts a blueprint it is like environment which is used for creating objects
# * 4 pillars of class
# 1. inheritance :- it is used to inherit properities from its parent class
# 2. encapsulation :- it is used to restict direct access to  some data
# 3. polymorphism :- it means "One name, many forms."
# 4. abstraction :- it hide the information

# %%
def find_len(lst):
    print(len(lst))
find_len([12,1,2,3,4,4])
# Out:
# 6

# %% [markdown]
# ### method
# joh bhi apn koi function kisi class ka andr define krta hai ussa method bolta hai (class ka andr function)
#
# function ka andr apan ko koi parameter pass karvana hota hai

# %%
#example
class ClassRoom:
    blackboard="yes" ## class variable
    ac="yes" ## class variable
    student="yes" ## class variable
    wifi="yes" ## class variable
    chalk="yes" ## class variable
    def show(saloni):
        pass
cr=ClassRoom()
cr.wifi
# Out:
# 'yes'

# %%
class Classname:
    pass

# %%
class College:
    college_name="CIT"
    address="sirohi"
st=College()
print(st.address)
print(st.college_name)
# Out:
# sirohi
# CIT

# %%
class Company:
    company_name="upflairs pvt ltd"
    company_address="pratap nagar jaipur"
    def company_details(self):
        print(f"My Company name is{self.company_name} and i am from jaipur")
        print(f"company address is {self.company_address}")
        #return" i do not have details"

ct=Company()
print(ct.company_address)
print(ct.company_details())
print(ct.company_name)
# Out:
# pratap nagar jaipur
# My Company name isupflairs pvt ltd and i am from jaipur
# company address is pratap nagar jaipur
# None
# upflairs pvt ltd

# %%
print(ct.company_details())
# Out:
# My Company name isupflairs pvt ltd and i am from jaipur
# company address is pratap nagar jaipur
# None

# %%
class Developer:
    salary="30k"
    position="python developer"
    def developer_details(self,developer_name,developer_address):
        lst=[]
        lst.extend([developer_name,developer_address])
        return lst
    
dev=Developer()
dev.developer_details("saloni agarwal","jaipur")
# Out:
# ['saloni agarwal', 'jaipur']
